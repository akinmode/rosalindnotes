# %% [markdown]
# # Counting Point Mutations

# %%
sample1 = "GAGCCTACTAACGGGAT"
sample2 = "CATCGTAATGACGGCCT"

# %%
def ham_distance(sample1, sample2):
    return sum([sample1[idx] != sample2[idx] for idx, i in enumerate(sample1)])

# %%
ham_distance(sample1, sample2)
# Out:
# 7

# %%
test1 = "..."
test2 = "..."

# %%
ham_distance(test1, test2)
# Out:
# 501
